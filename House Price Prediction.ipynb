# %%
import pandas as pd

# Load the dataset
data = pd.read_csv(r'C:\Users\Mohamed Ali\OneDrive\Desktop\Naan Mudhalvan\Assignments\Assignment 2\Housing.csv')

# %%
import matplotlib.pyplot as plt

# Example: Histogram of the 'Price' attribute
plt.hist(data['price'])
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
# Example: Scatter plot of 'Area' vs. 'Price'
plt.scatter(data['area'], data['price'])
plt.xlabel('Area')
plt.ylabel('Price')
plt.show()

# %%
import seaborn as sns

# Example: Heatmap of correlation matrix
correlation_matrix = data.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.show()
# Out:
# C:\Users\Mohamed Ali\AppData\Local\Temp\ipykernel_8780\3062234269.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()

# %%
# Example: Calculate mean and median of 'Price'
mean_price = data['price'].mean()
median_price = data['price'].median()
print('Mean Price:', mean_price)
print('Median Price:', median_price)
# Out:
# Mean Price: 4766729.247706422
# Median Price: 4340000.0

# %%
# Check for missing values
missing_values = data.isnull().sum()
print(missing_values)

# Example: Remove rows with missing values
data = data.dropna()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# furnishingstatus    0
# dtype: int64

# %%
# Example: Box plot to identify outliers in 'Price'
plt.boxplot(data['price'])
plt.xlabel('Price')
plt.show()

# %%
# Example: Perform one-hot encoding for 'Furnishing Status' column
encoded_data = pd.get_dummies(data, columns=['furnishingstatus'])

# %%
X = data.drop('price', axis=1)  # Independent variables
y = data['price']  # Dependent variable

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Load the dataset
data = pd.read_csv(r'C:\Users\Mohamed Ali\OneDrive\Desktop\Naan Mudhalvan\Assignments\Assignment 2\Housing.csv')

# Perform one-hot encoding for categorical columns
data_encoded = pd.get_dummies(data, columns=['furnishingstatus'])

# Split the data into dependent and independent variables
X = data_encoded.drop('price', axis=1)  # Independent variables
y = data_encoded['price']  # Dependent variable

# Scale the independent variables
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)

print('Mean Squared Error:', mse)
print('Root Mean Squared Error:', rmse)
print('Mean Absolute Error:', mae)
